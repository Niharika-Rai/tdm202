# %% [markdown]
# # Project 10 -- Niharka Rai

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# - ***Link to AI Chat History***: Please share a link to your chat if you used AI (ex. ChatGPT Shared Links). Link to AI Chat History: https://chatgpt.com/share/69d34ef4-ae00-8328-9e72-ea26d83db53e
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %% [markdown]
# 1.1 Containers provide a common working environment for the code no matter where it is located. They create a basic file system for the program to use while running but will not bother running an entirely new OS layer for every container deployed. Virtual machines are generally heavier and require more resources when compared to containers.
#
# 1.2 An image is a template (blueprint) used to create the containers. A registry is a storage system where images are pushed (uploaded) and pulled (downloaded). It basically stores many static images. Note: I got these definitions from the links attached in the question: https://www.geeksforgeeks.org/devops/what-is-docker-registry/
#
# 1.3 Apptainer is a good fit in restricted/HPC-like environments because it runs containers without requiring root privileges, improving security on shared systems. It integrates well with HPC infrastructure such as shared filesystems and job schedulers, and allows users to run containers as themselves rather than through a daemon. It can bootstrap images from Docker registries, making it convenient to reuse existing containers. Note: I used ChatGPT to refine my answer since it was only partially correct and missing the main reason.

# %% [markdown]
# ## Question 2

# %%
ls /home/x-nrai1
# Out:
# 'CCL ML.ipynb'
#  Desktop/
# 'Fall 2025 Seminar Check.ipynb'
#  Niharika-Rai-project01.ipynb
#  Niharika-Rai-project01.py
#  Niharika-Rai-project02.ipynb
#  Niharika-Rai-project02.py
#  Niharika-Rai-project03.ipynb
#  Niharika-Rai-project03.py
#  Niharika-Rai-project04.ipynb
#  Niharika-Rai-project05.ipynb
#  Niharika-Rai-project06.ipynb
#  Niharika-Rai-project07.ipynb
#  Niharika-Rai-project08.ipynb
#  Niharika-Rai-project09.ipynb
#  Niharika-Rai-project10.ipynb
#  Niharika-Rai-project11.ipynb
#  Niharika-Rai-project12.ipynb
#  Niharika-Rai-project14.ipynb
#  Niharika_Rai_APIs_project9.ipynb
#  Niharika_Rai_Containers1_project10.ipynb
#  Niharika_Rai_Optimization_project8.ipynb
#  Niharika_Rai_Polars_project6.ipynb
# 'Niharika_Rai_PyTorch&Tensors_project5.ipynb'
#  Niharika_Rai_TDM202_project1.ipynb
#  Niharika_Rai_mongodb_project10.ipynb
#  Niharika_Rai_mongodb_project11.ipynb
#  Niharika_Rai_project1.ipynb
#  Niharika_Rai_project2.ipynb
#  Niharika_Rai_project3.ipynb
# ...

# %%
ls /home/x-nrai1/project_containers
# Out:
# Apptainer.def  hello.py  requirements.txt

# %%
cat /home/x-nrai1/project_containers/hello.py
# Out:
# # hello.py
# import logging
# from datetime import datetime
# from time import sleep
#
# # this will log everything into a file called hello.log
# logging.basicConfig(
#     level=logging.INFO,
#     filename="hello.log",
#     format="%(asctime)s - %(levelname)s - %(message)s",
# )
# logger = logging.getLogger(__name__)
#
#
# def main():
#     for i in range(3):
#         logger.info(f"[{datetime.now().time()}] hello from apptainer loop={i}")
#         sleep(1)
#
# if __name__ == "__main__":
#     main()

# %%
cat /home/x-nrai1/project_containers/Apptainer.def
# Out:
# # project3/Apptainer.def
# Bootstrap: # registry location you are bootstrapping from
# From: # the image you want to pull from the registry
#
# %files
#     # this is where you copy over the relevant files from your local workspace to your container workspace
#
# %post
#     # this is where you run the necessary bash commands to create the environment you want for your program to run in
#     # i.e. customizing base file structure, updating dependencies to ensure a stable environment, installing python requirements into the environment
#
#
# %environment
#     # this is where you can define environment variables you may need
#
# %runscript
#     # this is where you run the script for your program

# %% [markdown]
# 2.1 See output above. The project directory is a folder in my home directory called, "project_containers" which contains all the 3 required files.
#
# 2.2 See output above. This code shows the contents of the "hello.py" file.
#
# 2.3 See output above. This code shows the contents of the "Apptainer.def" file.

# %% [markdown]
# ## Question 3

# %%
cat /home/x-nrai1/project_containers/hello.log
# Out:
# 2026-04-06 00:23:34,669 - INFO - [00:23:34.669234] hello from apptainer loop=0
# 2026-04-06 00:23:35,669 - INFO - [00:23:35.669391] hello from apptainer loop=1
# 2026-04-06 00:23:36,669 - INFO - [00:23:36.669619] hello from apptainer loop=2
# 2026-04-06 00:37:55,819 - INFO - [00:37:55.819604] hello from apptainer loop=0
# 2026-04-06 00:37:55,819 - INFO - [00:37:55.819717] added logger here loop=0
# 2026-04-06 00:37:56,819 - INFO - [00:37:56.819857] hello from apptainer loop=1
# 2026-04-06 00:37:56,820 - INFO - [00:37:56.820096] added logger here loop=1
# 2026-04-06 00:37:57,820 - INFO - [00:37:57.820269] hello from apptainer loop=2
# 2026-04-06 00:37:57,820 - INFO - [00:37:57.820480] added logger here loop=2

# %% [markdown]
# 3.1 See output above. I added the modifications given in the sample code for hello.py and can see the output both in the terminal and the "hello.log" file. It wasn't clear from the sample code if I should delete the previous logger.info "hello from apptainer" code, used in question 2, so I kept it and added the logger.info "added logger here" code right below the previous logger.info code in the for loop in my "hello.py" file.
#
# 3.2 The Bootstrap parameter helps to specify the registry location we are pulling the image from. The From parameter helps to specify the image you want to pull from the registry. The %files is where we map/move the files from our local workspace to inside the container. The %post helps us to set up the environment by updating and installing the build dependencies and installing python dependencies. The %runscript helps us to run the script for our program.

# %% [markdown]
# ## Question 4

# %%
# !uname -m
# Out:
# x86_64

# %%
cat /home/x-nrai1/project_containers/info.txt
# Out:
# org.label-schema.build-arch: amd64
# org.label-schema.build-date: Monday_6_April_2026_1:5:8_EDT
# org.label-schema.schema-version: 1.0
# org.label-schema.usage.apptainer.version: 1.4.2
# org.label-schema.usage.singularity.deffile.bootstrap: docker
# org.label-schema.usage.singularity.deffile.from: python:3.11-slim

# %% [markdown]
# 4.1 See output above.
#
# 4.2 See output above. I also added my project directory location right before info.txt since this file was created inside my project directory after I ran the bash commands in the terminal.

# %% [markdown]
# ## Question 5

# %%
cat /home/x-nrai1/project_containers/hello.log
# Out:
# 2026-04-06 00:23:34,669 - INFO - [00:23:34.669234] hello from apptainer loop=0
# 2026-04-06 00:23:35,669 - INFO - [00:23:35.669391] hello from apptainer loop=1
# 2026-04-06 00:23:36,669 - INFO - [00:23:36.669619] hello from apptainer loop=2
# 2026-04-06 00:37:55,819 - INFO - [00:37:55.819604] hello from apptainer loop=0
# 2026-04-06 00:37:55,819 - INFO - [00:37:55.819717] added logger here loop=0
# 2026-04-06 00:37:56,819 - INFO - [00:37:56.819857] hello from apptainer loop=1
# 2026-04-06 00:37:56,820 - INFO - [00:37:56.820096] added logger here loop=1
# 2026-04-06 00:37:57,820 - INFO - [00:37:57.820269] hello from apptainer loop=2
# 2026-04-06 00:37:57,820 - INFO - [00:37:57.820480] added logger here loop=2
# 2026-04-06 01:14:42,075 - INFO - [01:14:42.075020] hello from apptainer loop=0
# 2026-04-06 01:14:42,075 - INFO - [01:14:42.075121] added logger here loop=0
# 2026-04-06 01:14:43,075 - INFO - [01:14:43.075247] hello from apptainer loop=1
# ...

# %% [markdown]
# 5.1 See output above. The contents after both Part A and Part B edits are seen above.
#
# 5.2 Bind mounts speed up development by allowing code changes on the host system to be immediately visible inside the container. This removes the need to rebuild the container image after every change, enabling faster iteration and testing. Note: I used ChatGPT to refine my answer so it is within 1-2 sentences.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
